# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=300

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/data_clean.csv',index_col=0)
df
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4     5    1  2010    67       S
# 2     36.0    118.0   8.0     5    2  2010    72       C
# 3     12.0    149.0  12.6     5    3  2010    74      PS
# 4     18.0    313.0  11.5     5    4  2010    62       S
# 5      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4     5    1  2010    67       C
# 155   30.0    193.0   6.9     9   26  2010    70      PS
# 156    NaN    145.0  13.2     9   27  2010    77       S
# 157   14.0    191.0  14.3     9   28  2010    75       S
# 158   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 1   41.0    190.0   7.4     5    1  2010    67       S
# 2   36.0    118.0   8.0     5    2  2010    72       C
# 3   12.0    149.0  12.6     5    3  2010    74      PS
# 4   18.0    313.0  11.5     5    4  2010    62       S
# 5    NaN      NaN  14.3     5    5  2010    56       S

# %%
df.describe()
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 11.1+ KB

# %%
df['Month']
# Out:
# 1      5
# 2      5
# 3      5
# 4      5
# 5      5
#       ..
# 154    5
# 155    9
# 156    9
# 157    9
# 158    9
# Name: Month, Length: 158, dtype: object

# %%
df['Month'].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
df['Month'].value_counts()
# Out:
# Month
# 9      34
# 5      31
# 7      31
# 8      31
# 6      30
# May     1
# Name: count, dtype: int64

# %%
df['Month'].replace('May','5',inplace=True)

# %%
df['Month'].unique()
# Out:
# array(['5', '6', '7', '8', '9'], dtype=object)

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df['Month'] = df['Month'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 1 to 158
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    int32
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int32(1), int64(3), object(1)
# memory usage: 10.5+ KB

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4      5    1  2010    67       S
# 2     36.0    118.0   8.0      5    2  2010    72       C
# 3     12.0    149.0  12.6      5    3  2010    74      PS
# 4     18.0    313.0  11.5      5    4  2010    62       S
# 5      NaN      NaN  14.3      5    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4      5    1  2010    67       C
# 155   30.0    193.0   6.9      9   26  2010    70      PS
# 156    NaN    145.0  13.2      9   27  2010    77       S
# 157   14.0    191.0  14.3      9   28  2010    75       S
# 158   18.0    131.0   8.0      9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 154    False
# 155    False
# 156    False
# 157     True
# 158    False
# Length: 158, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 157   14.0    191.0  14.3      9   28  2010    75       S

# %%
df[df.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 151   14.0    191.0  14.3      9   28  2010    75       S
# 157   14.0    191.0  14.3      9   28  2010    75       S

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (157, 8)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Year'],inplace=True)

# %%
df.head(10)
# Out:
#     Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 1    41.0    190.0   7.4      5    1    67       S
# 2    36.0    118.0   8.0      5    2    72       C
# 3    12.0    149.0  12.6      5    3    74      PS
# 4    18.0    313.0  11.5      5    4    62       S
# 5     NaN      NaN  14.3      5    5    56       S
# 6    28.0      NaN  14.9      5    6    66       C
# 7    23.0    299.0   8.6      5    7    65      PS
# 8    19.0     99.0  13.8      5    8    59       C
# 9     8.0     19.0  20.1      5    9    61      PS
# 10    NaN    194.0   8.6      5   10    69       S

# %%
df.rename(columns={'Solar.R' : 'Solar', 'Temp' : 'Temprature'},inplace=True)

# %%
df.head(10)
# Out:
#     Ozone  Solar  Wind  Month  Day  Temprature Weather
# 1    41.0  190.0   7.4      5    1          67       S
# 2    36.0  118.0   8.0      5    2          72       C
# 3    12.0  149.0  12.6      5    3          74      PS
# 4    18.0  313.0  11.5      5    4          62       S
# 5     NaN    NaN  14.3      5    5          56       S
# 6    28.0    NaN  14.9      5    6          66       C
# 7    23.0  299.0   8.6      5    7          65      PS
# 8    19.0   99.0  13.8      5    8          59       C
# 9     8.0   19.0  20.1      5    9          61      PS
# 10    NaN  194.0   8.6      5   10          69       S

# %%
df.isna()
# Out:
#      Ozone  Solar   Wind  Month    Day  Temprature  Weather
# 1    False  False  False  False  False       False    False
# 2    False  False  False  False  False       False    False
# 3    False  False  False  False  False       False    False
# 4    False  False  False  False  False       False    False
# 5     True   True  False  False  False       False    False
# ..     ...    ...    ...    ...    ...         ...      ...
# 153  False  False  False  False  False       False    False
# 154  False  False  False  False  False       False    False
# 155  False  False  False  False  False       False    False
# 156   True  False  False  False  False       False    False
# 158  False  False  False  False  False       False    False
#
# [157 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Ozone         38
# Solar          7
# Wind           0
# Month          0
# Day            0
# Temprature     0
# Weather        3
# dtype: int64

# %%
for i in df.isna().sum():
    print((i/len(df))*100,"%")
# Out:
# 24.203821656050955 %
# 4.45859872611465 %
# 0.0 %
# 0.0 %
# 0.0 %
# 0.0 %
# 1.910828025477707 %

# %%
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
ozone_median = df['Ozone'].median()
ozone_median
# Out:
# 31.0

# %%
df['Ozone'].fillna(ozone_median, inplace=True)

# %%
df.isna().sum()
# Out:
# Ozone         0
# Solar         7
# Wind          0
# Month         0
# Day           0
# Temprature    0
# Weather       3
# dtype: int64

# %%
solar_mean=df['Solar'].mean()

# %%
df['Solar'].fillna(solar_mean,inplace=True)

# %%
df.isna().sum()
# Out:
# Ozone         0
# Solar         0
# Wind          0
# Month         0
# Day           0
# Temprature    0
# Weather       3
# dtype: int64

# %%
df['Weather'].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %%
df['Weather'].mode()
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
df['Weather'].fillna(df['Weather'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Ozone         0
# Solar         0
# Wind          0
# Month         0
# Day           0
# Temprature    0
# Weather       0
# dtype: int64

# %%
df.head(10)
# Out:
#     Ozone       Solar  Wind  Month  Day  Temprature Weather
# 1    41.0  190.000000   7.4      5    1          67       S
# 2    36.0  118.000000   8.0      5    2          72       C
# 3    12.0  149.000000  12.6      5    3          74      PS
# 4    18.0  313.000000  11.5      5    4          62       S
# 5    31.0  185.366667  14.3      5    5          56       S
# 6    28.0  185.366667  14.9      5    6          66       C
# 7    23.0  299.000000   8.6      5    7          65      PS
# 8    19.0   99.000000  13.8      5    8          59       C
# 9     8.0   19.000000  20.1      5    9          61      PS
# 10   31.0  194.000000   8.6      5   10          69       S

# %%
sn.boxplot(x=df['Ozone'])
# Out:
# <Axes: xlabel='Ozone'>

# %%
def outliers_detection(data,columnName):
    q1 = data[columnName].quantile(0.25)
    q3 = data[columnName].quantile(0.75)
    iqr = q3-q1
    
    upper=q3+(1.5*iqr)
    lower=q1-(1.5*iqr)
    
    return lower,upper

# %%
outliers_detection(df,'Ozone')
# Out:
# (-15.0, 81.0)

# %%
df[df['Ozone']>81]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temprature Weather
# 30   115.0  223.0   5.7      5   30          79       C
# 62   135.0  269.0   4.1      7    1          84       S
# 69    97.0  267.0   6.3      7    8          92      PS
# 70    97.0  272.0   5.7      7    9          92       C
# 71    85.0  175.0   7.4      7   10          89      PS
# 86   108.0  223.0   8.0      7   25          85      PS
# 89    82.0  213.0   7.4      7   28          88       S
# 99   122.0  255.0   4.0      8    7          89       C
# 100   89.0  229.0  10.3      8    8          90      PS
# 101  110.0  207.0   8.0      8    9          90       C
# 117  168.0  238.0   3.4      8   25          81      PS
# 121  118.0  225.0   2.3      8   29          94       S
# 122   84.0  237.0   6.3      8   30          96       S
# 123   85.0  188.0   6.3      8   31          94       C
# 124   96.0  167.0   6.9      9    1          91       C
# 127   91.0  189.0   4.6      9    4          93      PS

# %%
df.loc[df['Ozone']>81,'Ozone']
# Out:
# 30     115.0
# 62     135.0
# 69      97.0
# 70      97.0
# 71      85.0
# 86     108.0
# 89      82.0
# 99     122.0
# 100     89.0
# 101    110.0
# 117    168.0
# 121    118.0
# 122     84.0
# 123     85.0
# 124     96.0
# 127     91.0
# Name: Ozone, dtype: float64

# %%
df.loc[df['Ozone']>81,'Ozone']=81

# %%
sn.boxplot(x=df['Ozone'])
# Out:
# <Axes: xlabel='Ozone'>

# %%
sn.boxplot(x=df['Wind'])
# Out:
# <Axes: xlabel='Wind'>

# %%
outliers_detection(df,'Wind')
# Out:
# (1.2500000000000009, 17.65)

# %%
df[df['Wind']>17.65]
# Out:
#     Ozone  Solar  Wind  Month  Day  Temprature Weather
# 9     8.0   19.0  20.1      5    9          61      PS
# 18    6.0   78.0  18.4      5   18          57       C
# 48   37.0  284.0  20.7      6   17          72       C

# %%
df.loc[df['Wind']>17.65,'Wind']
# Out:
# 9     20.1
# 18    18.4
# 48    20.7
# Name: Wind, dtype: float64

# %%
df.loc[df['Wind']>17.65,'Wind']=17.65
df[df['Wind']==17.65]
# Out:
#     Ozone  Solar   Wind  Month  Day  Temprature Weather
# 9     8.0   19.0  17.65      5    9          61      PS
# 18    6.0   78.0  17.65      5   18          57       C
# 48   37.0  284.0  17.65      6   17          72       C

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (157, 7)

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temprature', 'Weather'], dtype='object')

# %%
sn.pairplot(df)
# Out:
# C:\Users\Aditya_thalkari\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.corr(numeric_only=True)
# Out:
#                Ozone     Solar      Wind     Month       Day  Temprature
# Ozone       1.000000  0.317926 -0.522513  0.183089 -0.042835    0.662773
# Solar       0.317926  1.000000 -0.053534 -0.080237 -0.151007    0.260677
# Wind       -0.522513 -0.053534  1.000000 -0.162988  0.033374   -0.439939
# Month       0.183089 -0.080237 -0.162988  1.000000  0.041438    0.408060
# Day        -0.042835 -0.151007  0.033374  0.041438  1.000000   -0.122787
# Temprature  0.662773  0.260677 -0.439939  0.408060 -0.122787    1.000000

# %%
sn.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df = pd.get_dummies(data = df, columns=['Weather'],)

# %%
# def booleanToInt(data,colname):
#     data[colname]=data[colname].astype(int)
# booleanToInt(df,['Weather_C', 'Weather_PS', 'Weather_S'])

# %%
df['Weather_C']=df['Weather_C'].astype(int)
df['Weather_PS']=df['Weather_PS'].astype(int)
df['Weather_S']=df['Weather_S'].astype(int)

# %%
df
# Out:
#      Ozone       Solar  Wind  Month  Day  Temprature  Weather_C  Weather_PS  \
# 1     41.0  190.000000   7.4      5    1          67          0           0
# 2     36.0  118.000000   8.0      5    2          72          1           0
# 3     12.0  149.000000  12.6      5    3          74          0           1
# 4     18.0  313.000000  11.5      5    4          62          0           0
# 5     31.0  185.366667  14.3      5    5          56          0           0
# ..     ...         ...   ...    ...  ...         ...        ...         ...
# 153   20.0  223.000000  11.5      9   30          68          0           0
# 154   41.0  190.000000   7.4      5    1          67          1           0
# 155   30.0  193.000000   6.9      9   26          70          0           1
# 156   31.0  145.000000  13.2      9   27          77          0           0
# 158   18.0  131.000000   8.0      9   29          76          1           0
#
#      Weather_S
# 1            1
# 2            0
# ...

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temprature', 'Weather_C',
#        'Weather_PS', 'Weather_S'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
sc = StandardScaler()

# %%
sc.fit_transform(df)
# Out:
# array([[ 0.19019358,  0.05342774, -0.73459309, ..., -0.67357531,
#         -0.65366102,  1.2545001 ],
#        [-0.03297826, -0.7768163 , -0.55759177, ...,  1.48461498,
#         -0.65366102, -0.79713027],
#        [-1.10420306, -0.41935011,  0.79941842, ..., -0.67357531,
#          1.52984494, -0.79713027],
#        ...,
#        [-0.30078446,  0.08802124, -0.8820942 , ..., -0.67357531,
#          1.52984494, -0.79713027],
#        [-0.25615009, -0.46547478,  0.97641975, ..., -0.67357531,
#         -0.65366102,  1.2545001 ],
#        [-0.83639686, -0.62691113, -0.55759177, ...,  1.48461498,
#         -0.65366102, -0.79713027]])

# %%
df = pd.DataFrame(sc.fit_transform(df),columns=['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temprature', 'Weather_C',
       'Weather_PS', 'Weather_S'])

# %%
df.describe()
# Out:
#               Ozone         Solar          Wind         Month           Day  \
# count  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02
# mean  -3.394312e-17 -9.051500e-17  1.470869e-16  1.810300e-16 -2.262875e-17
# std    1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00
# min   -1.595181e+00 -2.056776e+00 -2.416106e+00 -1.412198e+00 -1.668937e+00
# 25%   -7.024938e-01 -6.730358e-01 -7.345931e-01 -7.127815e-01 -8.864446e-01
# 50%   -2.561501e-01  8.802124e-02 -5.608800e-02 -1.336465e-02  7.832041e-03
# 75%    3.687310e-01  8.029536e-01  4.749160e-01  6.860522e-01  9.021087e-01
# max    1.975568e+00  1.713916e+00  2.289180e+00  1.385469e+00  1.684601e+00
#
#          Temprature     Weather_C    Weather_PS     Weather_S
# count  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02
# mean   2.036587e-16  4.242891e-17 -8.485781e-18 -7.849347e-17
# std    1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00
# ...

# %%
# minmaxScaler

# %%
# mn=MinMaxScaler()

# %%
# mn.fit_transform(df)

# %%
# min_max=pd.DataFrame(mn.fit_transform(df),columns=df.columns)
# min_max.describe()
